# %% [markdown]
# # 추론 환경 설정\n이 노트북은 추론에 필요한 Python 패키지를 설치하고, Hugging Face Hub에서 사전 학습된 모델들을 다운로드하는 과정을 안내합니다.

# %% [markdown]
# ## 1. Python 패키지 설치\n프로젝트에 필요한 모든 패키지는 프로젝트 루트 디렉터리의 `requirements.txt` 파일에 명시되어 있습니다.\n아래 명령어를 터미널에서 실행하여 모든 의존성을 한 번에 설치하세요.\n```bash\npip install -r requirements.txt\n```

# %% [markdown]
# ## 2. 사전 학습된 모델 다운로드\n아래 코드는 RAG 파이프라인에 사용되는 임베딩, 생성, 리랭커 모델을 `models/` 디렉터리로 다운로드합니다.\n이 작업은 한 번만 실행하면 됩니다. (`scripts/download_models.py` 스크립트를 실행합니다.)

# %%
# `scripts/download_models.py` 스크립트를 실행하여 모델을 다운로드합니다.\n# 노트북의 현재 위치가 'notebooks' 폴더이므로, 상위 디렉터리로 이동하여 실행합니다.\n!python ../scripts/download_models.py
